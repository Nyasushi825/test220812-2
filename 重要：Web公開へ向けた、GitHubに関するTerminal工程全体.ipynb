# %%
PS C:\Users\mcuser2> cd ./Desktop/Python-Udemy/Imanyu/Streamlit
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git init
PS C:\Users\mcuser2> cd ./Desktop/Python-Udemy/Imanyu/Streamlit
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git init
Reinitialized existing Git repository in C:/Users/mcuser2/Desktop/Python-Udemy/Imanyu/Streamlit/.git/
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git remote add origin https://github.com/Nyasushi825/test220812-2.git
error: remote origin already exists.
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git remote rm origin
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit>  git remote add origin https://github.com/Nyasushi825/test220812-2.git
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> pip freeze
    
alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work

altair==4.2.0

anaconda-client==1.7.2
anaconda-navigator==2.2.0
:
matplotlib @ file:///C:/ci/matplotlib-suite_1613408055530/work
numpy @ file:///C:/ci/numpy_and_numpy_base_1618497418457/work
        
Pillow @ file:///C:/ci/pillow_1617386341487/work
pandas @ file:///C:/ci/pandas_1618365634936/work
        
python-dateutil @ file:///home/ktietz/src/ci/python-dateutil_1611928101742/work
python-jsonrpc-server @ file:///tmp/build/80754af9/python-jsonrpc-server_1600278539111/work
python-language-server @ file:///tmp/build/80754af9/python-language-server_1607972495879/work
    
streamlit==1.11.1
:

    
    
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> pip freeze| grep streamlit
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> pip list | find "streamlit"
FIND: Parameter format not correct
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git add .
warning: in the working copy of '.ipynb_checkpoints/sample-checkpoint.py', LF will be replaced by CRLF the next time Git touches it
warning: in the working copy of 'sample.py', LF will be replaced by CRLF the next time Git touches it
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git commit -m'1st commit'
Author identity unknown

*** Please tell me who you are.

Run

  git config --global user.email "you@example.com"
  git config --global user.name "Your Name"

to set your account's default identity.
Omit --global to set the identity only in this repository.

fatal: unable to auto-detect email address (got 'Nomura@DESKTOP-531P0ST.(none)')
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit>  git config --global user.email "yasushi.nomura825@gmail.com"
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git commit -m'1st commit'
[master (root-commit) 7d2e2df] 1st commit
 14 files changed, 1474 insertions(+)
 create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
 create mode 100644 .ipynb_checkpoints/main-checkpoint.py
 create mode 100644 .ipynb_checkpoints/main2-checkpoint.py
 create mode 100644 ".ipynb_checkpoints/main3\342\230\205_for_deployment-checkpoint.py"
 create mode 100644 .ipynb_checkpoints/requirements-checkpoint.txt
 create mode 100644 .ipynb_checkpoints/sample-checkpoint.py
 create mode 100644 Untitled.ipynb
 create mode 100644 china_usa.py
 create mode 100644 main.py
 create mode 100644 main2.py
 create mode 100644 "main3\342\230\205_for_deployment.py"
 create mode 100644 requirements.txt
 create mode 100644 sample.py
 create mode 100644 sunny_hose_clean.jpg
PS C:\Users\mcuser2\Desktop\Python-Udemy\Imanyu\Streamlit> git push origin master
