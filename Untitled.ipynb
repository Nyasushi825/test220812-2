# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
df= pd.DataFrame({
    '1列目':[1,2,3,4],
    '2列目':[10,20,30,40]
    
})

# %%
df
# Out:
#    1列目  2列目
# 0    1   10
# 1    2   20
# 2    3   30
# 3    4   40

# %%
st.title('Streamlit超入門')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
streamlit run main.py
# Out:
#   File "<ipython-input-14-2e02c77d4725>", line 1
#     streamlit run main.py
#               ^
# SyntaxError: invalid syntax

# %%
streamlit run main.py
# Out:
#   File "<ipython-input-15-2e02c77d4725>", line 1
#     streamlit run main.py
#               ^
# SyntaxError: invalid syntax

# %%
pip install jupyter-console
# Out:
# Requirement already satisfied: jupyter-console in c:\users\mcuser2\anaconda3\lib\site-packages (6.4.0)
# Requirement already satisfied: ipykernel in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-console) (5.3.4)
# Requirement already satisfied: pygments in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-console) (2.8.1)
# Requirement already satisfied: jupyter-client in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-console) (6.1.12)
# Requirement already satisfied: ipython in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-console) (7.22.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-console) (3.0.17)
# Requirement already satisfied: wcwidth in c:\users\mcuser2\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console) (0.2.5)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipykernel->jupyter-console) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipykernel->jupyter-console) (6.1)
# Requirement already satisfied: decorator in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (5.0.6)
# Requirement already satisfied: backcall in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (0.17.2)
# Requirement already satisfied: pickleshare in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (0.7.5)
# Requirement already satisfied: colorama in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython->jupyter-console) (52.0.0.post20210125)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-client->jupyter-console) (2.8.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-client->jupyter-console) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-client->jupyter-console) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-console) (0.7.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->jupyter-console) (227)
# Requirement already satisfied: six>=1.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->jupyter-console) (1.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\mcuser2\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter-console) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\mcuser2\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (8.2.0)
# Requirement already satisfied: attrs>=16.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (3.20.1)
# Requirement already satisfied: watchdog in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (1.0.2)
# Requirement already satisfied: requests>=2.4 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (1.2.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (12.5.1)
# Requirement already satisfied: altair>=3.2.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: validators>=0.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (3.10.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: python-dateutil in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: numpy in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (1.20.1)
# Requirement already satisfied: semver in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: packaging>=14.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (20.9)
# Requirement already satisfied: click>=7.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: pympler>=0.9 in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: toml in c:\users\mcuser2\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in c:\users\mcuser2\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\mcuser2\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jinja2 in c:\users\mcuser2\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mcuser2\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mcuser2\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mcuser2\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.10)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.8.1)
# Requirement already satisfied: tzdata in c:\users\mcuser2\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.1)
# Requirement already satisfied: backports.zoneinfo in c:\users\mcuser2\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\mcuser2\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.0.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\mcuser2\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mcuser2\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\mcuser2\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: ipython-genutils in c:\users\mcuser2\anaconda3\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.17)
# Requirement already satisfied: backcall in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: colorama in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\mcuser2\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: jupyter-core in c:\users\mcuser2\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: argon2-cffi in c:\users\mcuser2\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\mcuser2\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mcuser2\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\mcuser2\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: wcwidth in c:\users\mcuser2\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\mcuser2\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.5)
# Requirement already satisfied: testpath in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: bleach in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mcuser2\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: pycparser in c:\users\mcuser2\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: async-generator in c:\users\mcuser2\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\mcuser2\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\mcuser2\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)

# %%
st.title('Streamlit超入門')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
st.write('DataFrame')

# %%
streamlit hello
# Out:
#   File "<ipython-input-20-c7a1b683aa76>", line 1
#     streamlit hello
#               ^
# SyntaxError: invalid syntax

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# altair                             4.2.0
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# backports.zoneinfo                 0.2.1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# blinker                            1.5
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         5.2.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# chromedriver-binary                103.0.5060.53.0
# chromedriver-binary-auto           0.1.2
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# commonmark                         0.9.1
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# gitdb                              4.0.9
# GitPython                          3.1.27
# glob2                              0.7
# google-api-core                    2.8.2
# google-api-python-client           2.52.0
# google-auth                        2.9.0
# google-auth-httplib2               0.1.0
# google-auth-oauthlib               0.5.2
# google-cloud-vision                3.0.0
# googleapis-common-protos           1.56.3
# greenlet                           1.0.0
# grpcio                             1.47.0
# grpcio-status                      1.47.0
# gspread                            5.4.0
# gspread-dataframe                  3.3.0
# gspread-formatting                 1.0.6
# h11                                0.13.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# httplib2                           0.20.4
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# install                            1.3.5
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# japanize-matplotlib                1.1.3
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# jpholiday                          0.1.8
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# lightgbm                           3.3.2
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# opencv-python                      4.6.0.66
# openpyxl                           3.0.7
# outcome                            1.1.0
# packaging                          20.9
# pandas                             1.2.4Note: you may need to restart the kernel to use updated packages.
#
# pandas-datareader                  0.10.0
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                22.2.2
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# proto-plus                         1.20.6
# protobuf                           3.20.1
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyarrow                            9.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydeck                             0.7.1
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# Pympler                            1.0.1
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyperclip                          1.8.2
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# pytz-deprecation-shim              0.1.0.post0
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# requests-oauthlib                  1.3.1
# rich                               12.5.1
# rope                               0.18.0
# rsa                                4.8
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# selenium                           4.3.0
# semver                             2.13.0
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# smmap                              5.0.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sns                                0.1
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# streamlit                          1.11.1
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# trio                               0.20.0
# trio-websocket                     0.9.2
# typed-ast                          1.4.2
# typing_extensions                  4.3.0
# tzdata                             2022.1
# tzlocal                            4.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# uritemplate                        4.1.1
# urllib3                            1.26.4
# validators                         0.20.0
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webdriver-manager                  3.5.4
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# wsproto                            1.1.0
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0
